# %% [markdown]
# ## Application Launch

# %% [markdown]
# ### Setup PythonNet bridge to connect with FlaUI Dll's

# %%
from flaui.lib.pythonnet_bridge import setup_pythonnet_bridge

setup_pythonnet_bridge()
# Out:
# 2022-05-02 16:16:12.527 | INFO     | flaui.lib.pythonnet_bridge:setup_pythonnet_bridge:21 - Added FlaUI.Core DLL from C:\Users\amrut\PythonProjects\flaui-uiautomation-wrapper\flaui\bin\FlaUI.Core.dll to PythonNet bridge
# 2022-05-02 16:16:12.539 | INFO     | flaui.lib.pythonnet_bridge:setup_pythonnet_bridge:21 - Added FlaUI.UIA2 DLL from C:\Users\amrut\PythonProjects\flaui-uiautomation-wrapper\flaui\bin\FlaUI.UIA2.dll to PythonNet bridge
# 2022-05-02 16:16:12.556 | INFO     | flaui.lib.pythonnet_bridge:setup_pythonnet_bridge:21 - Added FlaUI.UIA3 DLL from C:\Users\amrut\PythonProjects\flaui-uiautomation-wrapper\flaui\bin\FlaUI.UIA3.dll to PythonNet bridge
# 2022-05-02 16:16:12.559 | INFO     | flaui.lib.pythonnet_bridge:setup_pythonnet_bridge:21 - Added Interop.UIAutomationClient DLL from C:\Users\amrut\PythonProjects\flaui-uiautomation-wrapper\flaui\bin\Interop.UIAutomationClient.dll to PythonNet bridge

# %% [markdown]
# ### Import FlaUI dependencies

# %%
from FlaUI.UIA3 import UIA3Automation
from FlaUI.Core import Application
automation = UIA3Automation()

# %% [markdown]
# ### Launch notepad application and print PID

# %%
app = Application.Launch('notepad.exe')
print(f'Notepad PID - {app.get_ProcessId()}')

import PIL.ImageGrab

im = PIL.ImageGrab.grab()
im.copy()
# Out:
# Notepad PID - 17492
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
app.Close()
# Out:
# True
